# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Book_Purchased.csv')

df # 400 rows × 6 columns
# Out:
#                ID  Gender  Age   Salary  VIP  Purchased
# 0    BOOK62498940    Male   22  20900.0    0          0
# 1    BOOK63243776    Male   43  22000.0    0          0
# 2    BOOK62674300  Female   29  47300.0    0          0
# 3    BOOK62412984  Female   30  62700.0    0          0
# 4    BOOK63216008    Male   22  83600.0    0          0
# ..            ...     ...  ...      ...  ...        ...
# 395  BOOK62767452  Female   49  45100.0    1          1
# 396  BOOK62824284    Male   54  25300.0    1          1
# 397  BOOK62617184  Female   53  22000.0    0          1
# 398  BOOK63020072    Male   23  36300.0    0          0
# 399  BOOK62376164  Female   52  39600.0    1          1
#
# [400 rows x 6 columns]

# %%
df.describe()
# Out:
#              Age        Salary        VIP   Purchased
# count  400.00000     400.00000  400.00000  400.000000
# mean    41.26750   77722.69225    0.28500    0.362500
# std     11.40685   39753.01603    0.45198    0.481324
# min     20.00000   16500.00000    0.00000    0.000000
# 25%     33.00000   47300.00000    0.00000    0.000000
# 50%     40.00000   77000.00000    0.00000    0.000000
# 75%     49.00000   96800.00000    1.00000    1.000000
# max     96.00000  257789.00000    1.00000    1.000000

# %%
df.describe(include='object')
# Out:
#                   ID  Gender
# count            400     400
# unique           400       2
# top     BOOK62498940  Female
# freq               1     204
